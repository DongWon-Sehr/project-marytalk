# %%
import  urllib.request
import selenium
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from bs4 import BeautifulSoup
import requests
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
from datetime import datetime
import time
import sys
import tqdm
import selenium.common.exceptions as sce

from getpass import getpass

# %%
loc_list = []

# %%
def insta_img_search(key_word):
    
    # 전역변수 loc_list 사용
    global loc_list
    
    # 웹 크롤링에 사용할 웹-드라이버 설정
    driver = Chrome('c:/chromedriver.exe')
    
    # 세션 클래스 생성
    session = requests.Session()
    
    # 요청 보낼 때 header와 함께 전송
    header = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
               AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36", 
              "Accept":"text/html,application/xhtml+xml,application/xml;\
              q=0.9,imgwebp,*/*;q=0.8"}
    
    insta_image = 'https://www.instagram.com/'
    req = session.get(insta_image, headers=header)
    driver.get(insta_image)
    time.sleep(2.5 + abs(np.random.randn()))

#################################################
#     # facebook으로 로그인하기

#     try:# 페이스북으로 로그인 클릭
#         driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[6]/button/span[2]').click()
    
#     except sce.NoSuchElementException:
#         time.sleep(2.25 + np.random.rand() + np.random.rand())
#         login_two = driver.find_element_by_class_name('KPnG0')
#         login_two.click()
    
#     time.sleep(2.255 + abs(np.random.randn()))
    
#     # 아이디 입력 창을 찾아 변수에 저장
#     input_id = driver.find_element_by_id('email')
#     # 아이디 입력 창에 아이디를 입력
#     input_id.send_keys('hohae@paran.com')
#     time.sleep(2.4182 + abs(np.random.randn()))
    
#     # 비밀번호 입력 창을 찾아 변수에 저장
#     input_pw = driver.find_element_by_id('pass')
#     # 비밀번호 입력 창에 비밀번호를 입력
#     input_pw.send_keys('dlqeo1019.')
#     # 로그인 버튼의 위치를 찾아 변수에 저장
#     submit_b = driver.find_element_by_id('loginbutton')
    
#     # 로그인 버튼 클릭
#     submit_b.submit()
#     time.sleep(2.1982 + abs(np.random.randn()) + abs(np.random.randn()))

#     # facebook으로 로그인하기 끝
#######################################################

#######################################################
    # instagram으로 로그인하기
    
    # 아이디 입력 창을 찾아 변수에 저장
    xpath_id = """//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input"""
    input_id = driver.find_element_by_xpath(xpath_id)  # instagram login
    # 아이디 입력 창에 아이디를 입력
    input_id.send_keys('smarttuna')
    time.sleep(2.4182 + abs(np.random.randn()))
    
    # 비밀번호 입력 창을 찾아 변수에 저장
#    input_pw = driver.find_element_by_id('pass')  # facebook login
    xpath_pw = """//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input"""
    input_pw = driver.find_element_by_xpath(xpath_pw)  # instagram login
    # 비밀번호 입력 창에 비밀번호를 입력
    # getpass 모듈 getpass 함수로 입력값 마스킹 하여 받기
    password = getpass('password :')
    input_pw.send_keys(password)

    # 로그인 버튼의 위치를 찾아 변수에 저장
#    submit_b = driver.find_element_by_id('loginbutton')  # facebook login
    xpath_login = """//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[4]/button/div"""
    submit_b = driver.find_element_by_xpath(xpath_login)  # instagram login
    
    # 로그인 버튼 클릭
    submit_b.submit()
    time.sleep(1 + abs(np.random.randn()) + abs(np.random.randn()))

    # instagram으로 로그인 하기 끝
########################################################    
    
    # 알림설정을 하라는 귀찮은 창이 뜨면 '나중에 하기' 클릭하기
    try:
        time.sleep(1)
        notify = driver.find_element_by_xpath('/html/body/div[4]/div/div/div[3]/button[2]')
        notify.click()
    
    except sce.ElementNotInteractableException:
        driver.find_element_by_css_selector('body > div.RnEpo.Yx5HN > div > div > div.mt3GC > button.aOOlW.HoLwm').click()

    time.sleep(np.random.rand() + 1)
    
    # 메인 화면 상단 검색창 찾아 keyword 입력
    try:
        # 인스타그램의 해시태그 검색창의 xpath를 찾아 keyword 입력
        search = driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input').send_keys(key_word, Keys.RETURN)
        driver.implicitly_wait(10)
        
    except sce.ElementNotInteractableException:
        # 예외처리
        search = driver.find_element_by_css_selector('#react-root > section > nav > div._8MQSO.Cx7Bp > div > div > div.LWmhU._0aCwM > input').send_keys(key_word, Keys.RETURN)
        driver.implicitly_wait(10)
    
    # inputbox에 검색어 입력 후 Enter-key => down-key => Enter-key 입력하기
    ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
    time.sleep(np.random.rand() + np.random.rand() + 1)
    ActionChains(driver).key_down(Keys.DOWN).key_up(Keys.DOWN).perform()
    time.sleep(np.random.rand() + np.random.rand() + 1)
    ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
    driver.implicitly_wait(10)

    time.sleep(np.random.rand() + np.random.rand() + 2)
    driver.implicitly_wait(5)

    # 검색 결과 페이지 소스 따오기 - 총 게시글 수 확인
    main_src = driver.page_source
    time.sleep(2)
    main_soup = BeautifulSoup(main_src, 'html.parser')
    time.sleep(1.5 + np.random.rand())
    board = main_soup.find('span', class_='g47SY')
    total_count = int(board.get_text())
    print("총 게시글 수: ",total_count)

    # 첫번째 게시글 클릭
    first_post = driver.find_element_by_class_name("eLAPa")
    time.sleep(np.random.rand() + np.random.rand() + 1)
    first_post.click()
    time.sleep(1.5 + np.random.rand())
    
    # total count 만큼 게시글 넘겨가며 크롤링
    for i in tqdm.tnrange(total_count):
        driver.implicitly_wait(10)
        pg_src = driver.page_source
        time.sleep(2)
        soup = BeautifulSoup(pg_src, 'html.parser')
        
        # 게시글에서 id와 위치태그가 있는 div 선택
        soup.find('div', 'o-MQd  ')
        time.sleep(1.5)
        
        # 위치태그 가져오기
        loc_html = soup.find('a','O4GlU')
        # 있으면 location 변수에 저장
        if loc_html:
            location = loc_html.get_text()
        # 없으면 np.nan으로 저장
        else:
            location = np.nan
        print('location :', location)

        
        # 작성자 id 가져오기
        id_div = soup.find('div','e1e1d')
        id_html = id_div.find('a')
        # 있으면 id_man에 저장
        if id_html:
            id_man = id_html.get_text()
        # 없으면 np.nan 저장
        else:
            id_man = np.nan
        print('id :', id_man)
        print()
        
        # 가져온 id, location 정보를 loc_list 리스트에 append
        loc_list.append((location, id_man))
        time.sleep(np.random.rand() + np.random.rand() + 0.75)
        
        # 다음으로 넘어가는 Xpath 지정
        if i == 0:
            next_x_path = '/html/body/div[4]/div[1]/div/div/a'        
        
        else:
            next_x_path = '/html/body/div[4]/div[1]/div/div/a[2]'
        
        next_btn = driver.find_element_by_xpath(next_x_path)
        next_btn.click()
        time.sleep(1.5)
        
#         if i == (total_count - 1):
#             print('더 이상 불러올 게시물이 없습니다.')
#             break

    session.close()
    driver.close()
    return loc_list

# %%
insta_img_search('송리단길미용실')
# Out:
# password :········
# 총 게시글 수:  673
# ...
# None
# location : nan
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/suuuuuuuzi/">suuuuuuuzi</a>
# id : suuuuuuuzi
#
# <a class="O4GlU" href="/explore/locations/103156077950206/">이음</a>
# location : 이음
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/eum__0415/">eum__0415</a>
# id : eum__0415
#
# <a class="O4GlU" href="/explore/locations/103156077950206/">이음</a>
# location : 이음
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/eum__0415/">eum__0415</a>
# id : eum__0415
#
# <a class="O4GlU" href="/explore/locations/2082456598529080/">어라운드비</a>
# location : 어라운드비
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/ab.suae/">ab.suae</a>
# id : ab.suae
#
# None
# location : nan
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/ksukyoung/">ksukyoung</a>
# id : ksukyoung
#
# <a class="O4GlU" href="/explore/locations/103156077950206/">이음</a>
# location : 이음
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/eum__0415/">eum__0415</a>
# id : eum__0415
#
# None
# location : nan
# ...

# %%
##########################################################
# 아래는 test용 코드

# %%
key_word = '송리단길 미용실'

# 웹 크롤링에 사용할 웹-드라이버 설정
driver = Chrome('c:/chromedriver.exe')

# 세션 클래스 생성
session = requests.Session()

# 요청 보낼 때 header와 함께 전송
header = {"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
           AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36", 
          "Accept":"text/html,application/xhtml+xml,application/xml;\
          q=0.9,imgwebp,*/*;q=0.8"}

insta_image = 'https://www.instagram.com/'
req = session.get(insta_image, headers=header)
driver.get(insta_image)
time.sleep(2.5 + abs(np.random.randn()))

#     try:# 페이스북으로 로그인 클릭
#         driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/article/div/div[1]/div/form/div[6]/button/span[2]').click()

#     except sce.NoSuchElementException:
#         time.sleep(2.25 + np.random.rand() + np.random.rand())
#         login_two = driver.find_element_by_class_name('KPnG0')
#         login_two.click()

#     time.sleep(2.255 + abs(np.random.randn()))

# 아이디 입력 창을 찾아 변수에 저장
input_id = driver.find_element_by_xpath("""//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[2]/div/label/input""")
# 아이디 입력 창에 아이디를 입력
input_id.send_keys('smarttuna')
time.sleep(2.4182 + abs(np.random.randn()))

# 비밀번호 입력 창을 찾아 변수에 저장
input_pw = driver.find_element_by_xpath("""//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[3]/div/label/input""")
# 비밀번호 입력 창에 비밀번호를 입력
password = getpass('password :')
input_pw.send_keys(password)
# 로그인 버튼의 위치를 찾아 변수에 저장
submit_b = driver.find_element_by_xpath("""//*[@id="react-root"]/section/main/article/div[2]/div[1]/div/form/div[4]/button/div""")

# 로그인 버튼 클릭
submit_b.submit()
time.sleep(1 + abs(np.random.randn()) + abs(np.random.randn()))

# 알림설정을 하라는 귀찮은 창이 뜨면 '나중에 하기' 클릭하기
try:
    time.sleep(1)
    notify = driver.find_element_by_xpath('/html/body/div[4]/div/div/div[3]/button[2]')
    notify.click()

except sce.ElementNotInteractableException:
    driver.find_element_by_css_selector('body > div.RnEpo.Yx5HN > div > div > div.mt3GC > button.aOOlW.HoLwm').click()

#     driver.implicitly_wait(50)
time.sleep(np.random.rand() + 1)
try:
    # 인스타그램의 해시태그 검색창의 xpath를 찾는다
    search = driver.find_element_by_xpath('//*[@id="react-root"]/section/nav/div[2]/div/div/div[2]/input').send_keys(key_word, Keys.RETURN)
    driver.implicitly_wait(10)

except sce.ElementNotInteractableException:
    search = driver.find_element_by_css_selector('#react-root > section > nav > div._8MQSO.Cx7Bp > div > div > div.LWmhU._0aCwM > input').send_keys(key_word, Keys.RETURN)
    driver.implicitly_wait(10)

ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
time.sleep(np.random.rand() + np.random.rand() + 1)
ActionChains(driver).key_down(Keys.DOWN).key_up(Keys.DOWN).perform()
time.sleep(np.random.rand() + np.random.rand() + 1)
ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
driver.implicitly_wait(10)

time.sleep(np.random.rand() + np.random.rand() + 2)
# 인스타그램의 해시태그 검색창에 key_word를 입력
#     search.send_keys(key_word)
#     time.sleep(1.32 + np.random.rand() + np.random.rand())
# 입력된 key_word로 검색을 진행
#     driver.send_keys(Keys.ENTER)

driver.implicitly_wait(5)
#     time.sleep(2.3 + np.random.rand() + np.random.rand())
# 검색 결과 페이지 소스 따오기 - 총 게시글 수 확인
main_src = driver.page_source
time.sleep(2)
main_soup = BeautifulSoup(main_src, 'html.parser')
time.sleep(1.5 + np.random.rand())
board = main_soup.find('span', class_='g47SY')
total_count = int(board.get_text())
print("총 게시글 수: ",total_count)
#     # 총 게시글 수 까지는 잘 구해진다.


#     driver.page_source
# 첫번째 게시글 클릭
first_post = driver.find_element_by_class_name("eLAPa")
time.sleep(np.random.rand() + np.random.rand() + 1)
first_post.click()
time.sleep(1.5 + np.random.rand())

# %%
driver.implicitly_wait(10)
pg_src = driver.page_source
time.sleep(2)
soup = BeautifulSoup(pg_src, 'html.parser')
soup.find('div', 'o-MQd  ')
print(soup)
time.sleep(np.random.rand() + 1.25 + np.random.rand())
# Out:
# <html class="js logged-in client-root js-focus-visible sDN5V" lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>#송리단길미용실 해시태그 • Instagram 사진 및 동영상</title>
# <meta content="noimageindex, noarchive" name="robots"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover" id="viewport" name="viewport"/>
# <link href="/data/manifest.json" rel="manifest"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/es6/ConsumerUICommons.css/d579f6ebbdab.css" rel="preload" type="text/css"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/es6/ConsumerAsyncCommons.css/871d296b773f.css" rel="preload" type="text/css"/>
# ...

# %%
# 위치태그 가져오기
loc_html = soup.find('a','O4GlU')
print(loc_html)

# 있으면 location 변수에 저장
if loc_html:
    location = loc_html.get_text()
# 없으면 np.nan으로 저장
else:
    location = np.nan
print('location :', location)
# Out:
# <a class="O4GlU" href="/explore/locations/103156077950206/">이음</a>
# location : 이음

# %%
# 작성자 id 가져오기
id_div = soup.find('div','e1e1d')
id_html = id_div.find('a')
print(id_html)

# 있으면 id_man에 저장
if id_html:
    id_man = id_html.get_text()
# 없으면 np.nan 저장
else:
    id_man = np.nan
print('id :', id_man)
print()
# Out:
# <a class="sqdOP yWX7d _8A5w5 ZIAjV" href="/eum__0415/">eum__0415</a>
# id : eum__0415

# %%
# 여기까지 테스트
######################################################################

# %%
['송리단길미용실','홍대미용실','강남미용실','건대미용실','샤로수길미용실'
,'이대미용실','목동미용실']

# %%
loc_list
# Out:
# [(nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, nan),
#  (nan, 'suuuuuuuzi'),
#  (nan, 'suuuuuuuzi'),
#  (nan, 'suuuuuuuzi'),
#  ('이음', 'eum__0415'),
#  ('이음', 'eum__0415'),
#  ('어라운드비', 'ab.suae'),
#  (nan, 'ksukyoung'),
#  ('이음', 'eum__0415'),
#  (nan, 'waterparang'),
#  ('리엑스류베이직헤어샵 송파나루점', 'yuwol_june'),
#  ('리엑스류베이직헤어샵 송파나루점', 'yuwol_june'),
#  (nan, 'hi_lyxryu'),
#  ('Songpa District', 'grandwig'),
#  ('송파나루역', 'grandwig'),
#  ('12월애헤어', '12__hangyeol'),
#  ('12월애헤어', '12__hangyeol'),
#  ('이음', 'eum__0415'),
#  (nan, 'lyxryu_munjeongstation'),
#  (nan, 'hi_lyxryu'),
#  (nan, 'lyxryu_basic_songpanaru'),
#  (nan, 'lyxryu_jamsil'),
#  (nan, 'lyxryu_munjeong'),
#  ('Songpa District', 'choi_seonyu'),
#  (nan, 'hi_lyxryu'),
#  ('Seokchon Lake 석촌호수', '_high__noon'),
#  ('Songpa District', 'choi_seonyu'),
#  ('Songpa District', 'choi_seonyu'),
#  ('12월애헤어', '12__bsh'),
#  ('Songpa District', 'choi_seonyu'),
#  ('잠실어딘가...', 'cresc_ji'),
# ...
