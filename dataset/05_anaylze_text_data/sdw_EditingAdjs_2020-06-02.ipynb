# %%
import pickle
with open('./output_data/HairshopReviewFeatureNamesKeyword_2020-05-29.pickle', 'rb') as f:
    keywords = pickle.load(f)

# %%
#청결
san_pos_keywords = keywords[0][0]
san_neg_keywords = keywords[0][1]
san_neu_keywords = keywords[0][2]

#서비스(고객 만족도) 
#음식이 카테고리에 들어간 건 티나 커피, 토스트 등 
#장기간 머리를 하는 손님에게 서비스 차원에서 음식을 제공하는 미용실(서비스가 좋은 미용실이라 판단)이 있음
cs_pos_keywords = keywords[1][0]
cs_neg_keywords = keywords[1][1]
cs_neu_keywords = keywords[1][2]

#매장 분위기/인테리어
mood_pos_keywords= keywords[2][0]
mood_neg_keywords= keywords[2][1]   
mood_neu_keywords= keywords[2][2]
                  

#가격
price_pos_keywords= keywords[3][0]
price_neg_keywords= keywords[3][1]
price_neu_keywords= keywords[3][2]

# 위치/교통
loc_pos_keywords = keywords[4][0]
loc_neg_keywords = keywords[4][1]
loc_neu_keywords = keywords[4][2]

# 헤어 관련 만족도(디자이너 실력, 시술 후 헤어 상태 등 헤어 관련 키워드)
sat_pos_keywords = keywords[5][0]
sat_neg_keywords = keywords[5][1]
sat_neu_keywords = keywords[5][2]

# 그 외(카테고리 분류하기 애매한 단어들) 
etc_pos_keywords = keywords[6][0]
etc_neg_keywords = keywords[6][1]
etc_neu_keywords = keywords[6][2]

# %%
print(f'san_pos_keywords = {san_pos_keywords}')
print(f'san_neg_keywords = {san_neg_keywords}')
print(f'san_neu_keywords = {san_neu_keywords}')
print()
print(f'cs_pos_keywords = {cs_pos_keywords}')
print(f'cs_neg_keywords = {cs_neg_keywords}')
print(f'cs_neu_keywords = {cs_neu_keywords}')
print()
print(f'mood_pos_keywords = {mood_pos_keywords}')
print(f'mood_neg_keywords = {mood_neg_keywords}')
print(f'mood_neu_keywords = {mood_neu_keywords}')
print()
print(f'price_pos_keywords = {price_pos_keywords}')
print(f'price_neg_keywords = {price_neg_keywords}')
print(f'price_neu_keywords = {price_neu_keywords}')
print()
print(f'loc_pos_keywords = {loc_pos_keywords}')
print(f'loc_neg_keywords = {loc_neg_keywords}')
print(f'loc_neu_keywords = {loc_neu_keywords}')
print()
print(f'sat_pos_keywords = {sat_pos_keywords}')
print(f'sat_neg_keywords = {sat_neg_keywords}')
print(f'sat_neu_keywords = {sat_neu_keywords}')
print()
print(f'etc_pos_keywords = {etc_pos_keywords}')
print(f'etc_neg_keywords = {etc_neg_keywords}')
print(f'etc_neu_keywords = {etc_neu_keywords}')
# Out:
# san_pos_keywords = ['위생 철저', '상당히 깔끔', '항상 깨끗', '밝은', '통풍 이 잘', '위생 신경 쓰', '깨끗', '위생 적', '청결']
# san_neg_keywords = ['더럽', '너저분', '비위생', '불결']
# san_neu_keywords = ['위생', '정리 정돈']
#
# cs_pos_keywords = ['면서 마실', '주차장 있', '완비', '간식 내어주', '간식 제공 해', '가장 편안한', '변함없 는 서비스', '잡지', '주차 걱정 없', '기다림 없이', '쿠키 도 챙겨', '주차 가능', '배려 좋', '쿠션 도 준비', '주차 무료', '편하', '배려 돋보이', '새벽 시 영업', '쿠키 도 준비', '갈 마다 서비스', '헤어마사지', '가장 편하', '간식거리 도 챙겨', '반갑 게', '가장 친절 한', '상담 꼼꼼', '최 고급 브랜드', '편리 했 어요', '기본 음료', '가장 편하 고', '무료마사지', '간식 제공', '배려 서비스', '감동 친절', '대박 친절', '웰컴티', '완전 친절', '최 고급 서비스', '간식거리 주 셨', '무료주차권', '스낵', '가장 친절', '예약 도 편하', '친절한', '배려 넘', '가장 편한', '쿠키 가져다', '퀄리티 서비스', '주차장 무료', '친절', '감동', '편안', '배려 감동', '커피 가져다 주', '무료케어', '감사 너무 만족', '상냥', '대접 받 은', '감사 너무 친절', '주차 는 무료', '갈 마다 즐겁', '배려 느껴', '대접 받 는', '간식거리 도 준비', '배려', '갈 마다 정성', '방법 도 차근차근', '주차장 도', '갈 마다 친절', '합니다 언제나 친절', '배려 넘치', '상담 만족', '팩 도 감사', '공짜', '커피랑 다과 서비스', '반겨', '발렛 주차 가능', '무료 주차', '갈 마다 친절히', '챙겨', '발렛 파킹 가능']
# ...
