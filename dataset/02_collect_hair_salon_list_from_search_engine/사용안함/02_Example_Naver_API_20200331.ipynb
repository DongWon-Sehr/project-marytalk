# %% [markdown]
# ---
# ### 네이버 지도 API 이용 - 데이터 크롤링

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
pd.set_option('display.max_columns',50) # DataFrame truncation 없이 보기

import re
import datetime
import time
import requests
import math

# %%
# 네이버 API 인증 ID
client_id = 'sDYPCi0TlT6FFoKVbOTz'

# 네이버 API 인증 PW
client_secret = 'lyX1n9_ht3'

# %%
# 네이버 API로 지도검색 정보를 요청하는 함수
# request_naver_api(검색어, 시작번호, 조회개수)

def request_naver_api(keyword, start, display):
    
    # 기본 URL
    url = 'https://openapi.naver.com/v1/search/local.json'
    
    # 헤더에 담을 인증키 정보
    header = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret' : client_secret }

    # 쿼리스트링
    queryString = {
          'query' : '서울 ' + keyword
        , 'start' : str(start)
        , 'display' : str(display)
    }
    
    try: 
        # request 보내서 response_naver에 저장
        response_naver = requests.get(url, headers=header, params = queryString)
        if response_naver.status_code == 200: # 정상처리되면
            print ("[%s] URL Request Success" % datetime.datetime.now()) # 정상출력
            return response_naver.json() # 실행결과 dict 객체로 변환하여 반환
    except Exception as e: # 에러 발생시
        print(e) # 에러 메세지 출력
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url)) # 에러 URL 출력
        return None

# %%
# '서울 준오헤어'로 검색, 1번 데이터부터, 30개 요청
dict_result = request_naver_api('준오헤어', 1, 1)
# Out:
# [2020-04-06 19:58:33.119191] URL Request Success

# %%
# 총 검색결과 수 뽑기
total_count = dict_result['total'] 
total_count
# Out:
# 106

# %%
# 최대 요청 개수인 30으로 나누어서 반올림
# 요청할 회수
request_count = math.ceil(total_count / 30)
request_count
# Out:
# 4

# %%
# 요청 회수만큼 URL 만들어서 리스트에 저장
dict_list_naver=[]
for i in range(request_count):
    dict_list_naver.append(request_naver_api('준오헤어', 1 + 30 * i, 30))

dict_list_naver
# Out:
# [2020-04-06 19:58:33.284705] URL Request Success
# [2020-04-06 19:58:33.427319] URL Request Success
# [2020-04-06 19:58:33.561990] URL Request Success
# [2020-04-06 19:58:33.687661] URL Request Success
# [{'lastBuildDate': 'Mon, 06 Apr 2020 19:58:32 +0900',
#   'total': 106,
#   'start': 1,
#   'display': 30,
#   'items': [{'title': '<b>준오헤어</b> 강남2호점',
#     'link': 'https://junohairgangnam.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-536-6605',
#     'address': '서울특별시 서초구 서초동 1305',
#     'roadAddress': '서울특별시 서초구 강남대로 441 서산빌딩 3층',
#     'mapx': '314018',
#     'mapy': '544856'},
#    {'title': '<b>준오헤어</b> 목동41타워점',
#     'link': 'https://junohairmokdong41.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2649-0605',
#     'address': '서울특별시 양천구 목동 917-9',
#     'roadAddress': '서울특별시 양천구 목동동로 293 현대41타워 3층',
#     'mapx': '300831',
#     'mapy': '547930'},
#    {'title': '<b>준오헤어</b> 노원사거리점',
#     'link': 'http://blog.naver.com/hari4919',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-938-0605',
#     'address': '서울특별시 노원구 상계동 712',
#     'roadAddress': '서울특별시 노원구 동일로 1413 남성빌딩 3층 준오헤어',
#     'mapx': '317258',
#     'mapy': '561802'},
#    {'title': '<b>준오헤어</b> <b>서울</b>대입구역점',
#     'link': 'https://www.instagram.com/juno_sd1/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-882-0605',
#     'address': '서울특별시 관악구 봉천동 863-2',
#     'roadAddress': '서울특별시 관악구 관악로 163',
#     'mapx': '307514',
#     'mapy': '542492'},
#    {'title': '<b>준오헤어</b> 압구정로데오 1호점',
#     'link': 'https://junohairrode1.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-518-6050',
#     'address': '서울특별시 강남구 신사동 664-7',
#     'roadAddress': '서울특별시 강남구 선릉로 843',
#     'mapx': '315373',
#     'mapy': '547679'},
#    {'title': '<b>준오헤어</b> 노원역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3391-6605',
#     'address': '서울특별시 노원구 상계동 603-13',
#     'roadAddress': '서울특별시 노원구 상계로 61',
#     'mapx': '317426',
#     'mapy': '561961'},
#    {'title': '<b>준오헤어</b> 양재1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-574-6605',
#     'address': '서울특별시 서초구 양재동 1-11',
#     'roadAddress': '서울특별시 서초구 남부순환로 2626',
#     'mapx': '315133',
#     'mapy': '542960'},
#    {'title': '<b>준오헤어</b> 방배역점',
#     'link': 'https://junohairbangbae.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-533-0605',
#     'address': '서울특별시 서초구 방배동 908-10',
#     'roadAddress': '서울특별시 서초구 방배로 84',
#     'mapx': '311544',
#     'mapy': '542692'},
#    {'title': '<b>준오헤어</b> 잠실롯데월드몰점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3213-4605',
#     'address': '서울특별시 송파구 신천동 29',
#     'roadAddress': '서울특별시 송파구 올림픽로 300 6층',
#     'mapx': '320977',
#     'mapy': '546101'},
#    {'title': '<b>준오헤어</b> 여의도IFC몰점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-6137-5065',
#     'address': '서울특별시 영등포구 여의도동 23',
#     'roadAddress': '서울특별시 영등포구 국제금융로 10 IFC몰 L2층',
#     'mapx': '305316',
#     'mapy': '547560'},
#    {'title': '<b>준오헤어</b> 이수역점',
#     'link': 'http://junohairisu.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-595-0605',
#     'address': '서울특별시 서초구 방배동 3000-1',
#     'roadAddress': '서울특별시 서초구 동작대로 112',
#     'mapx': '310230',
#     'mapy': '543191'},
#    {'title': '<b>준오헤어</b> 잠실점',
#     'link': 'http://www.instagram.com/juno_jamsil',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-422-8605',
#     'address': '서울특별시 송파구 삼전동 1',
#     'roadAddress': '서울특별시 송파구 삼전로 102',
#     'mapx': '319837',
#     'mapy': '545407'},
#    {'title': '<b>준오헤어</b> 낙성대역점',
#     'link': 'https://www.instagram.com/juno.nsd/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-875-0605',
#     'address': '서울특별시 관악구 봉천동 1687-5',
#     'roadAddress': '서울특별시 관악구 남부순환로 1931',
#     'mapx': '308569',
#     'mapy': '542187'},
#    {'title': '<b>준오헤어</b> 구의역점',
#     'link': 'http://hairshop.KAKAO.com/4074',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3437-0605',
#     'address': '서울특별시 광진구 자양동 779',
#     'roadAddress': '서울특별시 광진구 아차산로 355',
#     'mapx': '319110',
#     'mapy': '548738'},
#    {'title': '<b>준오헤어</b> 종합운동장사거리점',
#     'link': 'https://www.instagram.com/juno_jamsil_sportscomplex',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-425-6605',
#     'address': '서울특별시 송파구 잠실동 175-6',
#     'roadAddress': '서울특별시 송파구 올림픽로 76 2층',
#     'mapx': '318794',
#     'mapy': '545890'},
#    {'title': '<b>준오헤어</b> 신촌점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-393-6050',
#     'address': '서울특별시 서대문구 창천동 31-36',
#     'roadAddress': '서울특별시 서대문구 연세로 24',
#     'mapx': '306292',
#     'mapy': '551153'},
#    {'title': '<b>준오헤어</b> 천호로데오점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-475-0605',
#     'address': '서울특별시 강동구 천호동 411-39',
#     'roadAddress': '서울특별시 강동구 천호대로157길 46',
#     'mapx': '323125',
#     'mapy': '548971'},
#    {'title': '<b>준오헤어</b> 대학로점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-744-0605',
#     'address': '서울특별시 종로구 동숭동 1-35',
#     'roadAddress': '서울특별시 종로구 대학로 132',
#     'mapx': '312061',
#     'mapy': '553900'},
#    {'title': '<b>준오헤어</b> <b>서울</b>대샤로수길점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-873-6050',
#     'address': '서울특별시 관악구 봉천동 855-11',
#     'roadAddress': '서울특별시 관악구 관악로 156 호윤빌딩 2층',
#     'mapx': '307565',
#     'mapy': '542408'},
#    {'title': '<b>준오헤어</b> 대치점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-563-1605',
#     'address': '서울특별시 강남구 대치동 1021-2',
#     'roadAddress': '서울특별시 강남구 도곡로 448',
#     'mapx': '317037',
#     'mapy': '544420'},
#    {'title': '<b>준오헤어</b> 천호역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-485-0605',
#     'address': '서울특별시 강동구 천호동 454-14',
#     'roadAddress': '서울특별시 강동구 천호대로 1023',
#     'mapx': '322953',
#     'mapy': '548804'},
#    {'title': '<b>준오헤어</b> 이대2호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-364-4970',
#     'address': '서울특별시 서대문구 대현동 37-3',
#     'roadAddress': '서울특별시 서대문구 이화여대7길 30',
#     'mapx': '306877',
#     'mapy': '551259'},
#    {'title': '<b>준오헤어</b> 합정메세나폴리스점',
#     'link': 'https://junohairhj.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3141-6050',
#     'address': '서울특별시 마포구 합정동 414',
#     'roadAddress': '서울특별시 마포구 양화로 45 메세나폴리스 지하1층 준오헤어',
#     'mapx': '304255',
#     'mapy': '550464'},
#    {'title': '<b>준오헤어</b> 가로수길점',
#     'link': 'https://junohairgarosugil.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3446-0605',
#     'address': '서울특별시 강남구 신사동 514-10',
#     'roadAddress': '서울특별시 강남구 도산대로 127',
#     'mapx': '313772',
#     'mapy': '546612'},
#    {'title': '<b>준오헤어</b> 홍대2호점',
#     'link': 'https://junohair2.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-332-1605',
#     'address': '서울특별시 마포구 서교동 362-4',
#     'roadAddress': '서울특별시 마포구 와우산로 79',
#     'mapx': '305047',
#     'mapy': '550472'},
#    {'title': '<b>준오헤어</b> 영등포점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2672-0605',
#     'address': '서울특별시 영등포구 영등포동3가 9-2',
#     'roadAddress': '서울특별시 영등포구 영중로 18',
#     'mapx': '303504',
#     'mapy': '546763'},
#    {'title': '<b>준오헤어</b> 선릉테헤란로점',
#     'link': 'https://junohairseolleung.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3452-0605',
#     'address': '서울특별시 강남구 삼성동 141-28',
#     'roadAddress': '서울특별시 강남구 테헤란로 409',
#     'mapx': '316243',
#     'mapy': '545237'},
#    {'title': '<b>준오헤어</b> 선릉역1호점',
#     'link': '',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-558-0605',
#     'address': '서울특별시 강남구 역삼동 705-24',
#     'roadAddress': '서울특별시 강남구 선릉로 515',
#     'mapx': '316055',
#     'mapy': '545244'},
#    {'title': '<b>준오헤어</b> 노원문화의거리점',
#     'link': 'https://blog.naver.com/kmjkjn',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 노원구 상계동 616-4',
#     'roadAddress': '서울특별시 노원구 노해로81길 16 3층 준오헤어노원문화의거리점',
#     'mapx': '317505',
#     'mapy': '561893'},
#    {'title': '<b>준오헤어</b> 남부터미널역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-581-0605',
#     'address': '서울특별시 서초구 서초동 1602-5',
#     'roadAddress': '서울특별시 서초구 서초중앙로 43 2층 준오헤어',
#     'mapx': '313140',
#     'mapy': '543061'}]},
#  {'lastBuildDate': 'Mon, 06 Apr 2020 19:58:32 +0900',
#   'total': 106,
#   'start': 31,
#   'display': 30,
#   'items': [{'title': '<b>준오헤어</b> 중계은행사거리점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2091-0605',
#     'address': '서울특별시 노원구 중계동 359-15',
#     'roadAddress': '서울특별시 노원구 중계로 220',
#     'mapx': '318644',
#     'mapy': '561361'},
#    {'title': '<b>준오헤어</b> 명일이마트점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3428-0605',
#     'address': '서울특별시 강동구 명일동 47-7',
#     'roadAddress': '서울특별시 강동구 동남로75길 5',
#     'mapx': '325617',
#     'mapy': '550563'},
#    {'title': '<b>준오헤어</b> 신림역1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-886-0605',
#     'address': '서울특별시 관악구 신림동 1433-49',
#     'roadAddress': '서울특별시 관악구 남부순환로 1601',
#     'mapx': '305430',
#     'mapy': '543009'},
#    {'title': '<b>준오헤어</b> 논현점',
#     'link': 'https://junonh.modoo.at',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-518-0605',
#     'address': '서울특별시 서초구 반포동 736-17',
#     'roadAddress': '서울특별시 서초구 강남대로 503 청하빌딩 3층 준오헤어 논현점',
#     'mapx': '313810',
#     'mapy': '545428'},
#    {'title': '<b>준오헤어</b> 문정역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-406-0605',
#     'address': '서울특별시 송파구 문정동 643-1',
#     'roadAddress': '서울특별시 송파구 법원로 114 엠스테이트 B동 지하 1층 119호',
#     'mapx': '322488',
#     'mapy': '542992'},
#    {'title': '<b>준오헤어</b> 가든준오IFC몰점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-6137-5605',
#     'address': '서울특별시 영등포구 여의도동 23',
#     'roadAddress': '서울특별시 영등포구 국제금융로 10 L1층',
#     'mapx': '305304',
#     'mapy': '547572'},
#    {'title': '<b>준오헤어</b> 명동3호점',
#     'link': 'http://hairshop.kakao.com/3992',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-776-0605',
#     'address': '서울특별시 중구 충무로2가 7-1',
#     'roadAddress': '서울특별시 중구 명동10길 41',
#     'mapx': '310605',
#     'mapy': '551581'},
#    {'title': '<b>준오헤어</b> 삼성역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-565-0605',
#     'address': '서울특별시 강남구 대치동 945-5',
#     'roadAddress': '서울특별시 강남구 테헤란로 528',
#     'mapx': '317264',
#     'mapy': '545525'},
#    {'title': '<b>준오헤어</b> 강변역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-446-0605',
#     'address': '서울특별시 광진구 구의동 631-1',
#     'roadAddress': '서울특별시 광진구 광나루로56길 29',
#     'mapx': '320303',
#     'mapy': '548681'},
#    {'title': '<b>준오헤어</b> 강서구청점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2692-0605',
#     'address': '서울특별시 강서구 화곡동 1095',
#     'roadAddress': '서울특별시 강서구 화곡로 347 그랜드아이파크 311호',
#     'mapx': '298703',
#     'mapy': '550914'},
#    {'title': '<b>준오헤어</b> 왕십리역 2호점 VIP',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 성동구 행당동 168-151',
#     'roadAddress': '서울특별시 성동구 왕십리광장로 17 3층 준오헤어 왕십리역 2호점 VIP',
#     'mapx': '315245',
#     'mapy': '551470'},
#    {'title': '<b>준오헤어</b> 왕십리역1호점',
#     'link': 'http://hairshop.kakao.com/store/4040',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2291-0605',
#     'address': '서울특별시 성동구 행당동 168-151',
#     'roadAddress': '서울특별시 성동구 왕십리광장로 17',
#     'mapx': '315242',
#     'mapy': '551462'},
#    {'title': '<b>준오헤어</b> 마포공덕점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-363-1605',
#     'address': '서울특별시 마포구 아현동 618-19',
#     'roadAddress': '서울특별시 마포구 마포대로 173-14 2층',
#     'mapx': '307736',
#     'mapy': '550374'},
#    {'title': '<b>준오헤어</b> 강남역스퀘어점',
#     'link': 'http://www.instagram.com/juno_gnsq',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-561-0605',
#     'address': '서울특별시 강남구 역삼동 821',
#     'roadAddress': '서울특별시 강남구 테헤란로 101 이즈타워 3층',
#     'mapx': '314255',
#     'mapy': '544506'},
#    {'title': '<b>준오헤어</b> 강남4호점',
#     'link': 'https://junohairgangnam04.modoo.at',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-563-0605',
#     'address': '서울특별시 강남구 역삼동 827-1',
#     'roadAddress': '서울특별시 강남구 테헤란로4길 25 2층준오헤어',
#     'mapx': '314455',
#     'mapy': '544298'},
#    {'title': '<b>준오헤어</b> 강남우성점',
#     'link': 'http://www.instagram.com/junohair_gnws',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3486-0605',
#     'address': '서울특별시 서초구 서초동 1337',
#     'roadAddress': '서울특별시 서초구 사임당로 174 2F',
#     'mapx': '314304',
#     'mapy': '543800'},
#    {'title': '<b>준오헤어</b> 송파아이파크점',
#     'link': 'https://iparkjuno.modoo.at',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-406-4605',
#     'address': '서울특별시 송파구 문정동 624',
#     'roadAddress': '서울특별시 송파구 법원로 55',
#     'mapx': '322565',
#     'mapy': '542313'},
#    {'title': '<b>준오헤어</b> 돈암2호점',
#     'link': 'http://blog.naver.com/d2juno',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-926-1605',
#     'address': '서울특별시 성북구 동선동1가 85-104',
#     'roadAddress': '서울특별시 성북구 동소문로22길 39',
#     'mapx': '313514',
#     'mapy': '554807'},
#    {'title': '<b>준오헤어</b> 강남우성사거리점',
#     'link': 'https://www.instagram.com/junohair_gnwstreet/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-537-0605',
#     'address': '서울특별시 강남구 역삼동 832',
#     'roadAddress': '서울특별시 강남구 강남대로 334',
#     'mapx': '314460',
#     'mapy': '543877'},
#    {'title': '<b>준오헤어</b> 한티역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-562-1605',
#     'address': '서울특별시 강남구 대치동 936-16',
#     'roadAddress': '서울특별시 강남구 선릉로64길 20',
#     'mapx': '316547',
#     'mapy': '544402'},
#    {'title': '<b>준오헤어</b> 연신내점',
#     'link': 'https://blog.naver.com/ysnjuno ',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-387-0605',
#     'address': '서울특별시 은평구 대조동 185-1',
#     'roadAddress': '서울특별시 은평구 통일로 845 2층 준오헤어 연신내점',
#     'mapx': '304968',
#     'mapy': '557918'},
#    {'title': '<b>준오헤어</b> 명일역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-481-0605',
#     'address': '서울특별시 강동구 명일동 312-95',
#     'roadAddress': '서울특별시 강동구 양재대로 1638',
#     'mapx': '324589',
#     'mapy': '550294'},
#    {'title': '<b>준오헤어</b> 여의도KBS별관점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 영등포구 여의도동 44-37',
#     'roadAddress': '서울특별시 영등포구 여의대방로 375 아일렉스타워 2층',
#     'mapx': '305682',
#     'mapy': '546844'},
#    {'title': '<b>준오헤어</b> 가든준오 용산아이파크몰점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2012-4387',
#     'address': '서울특별시 용산구 한강로3가 40-999',
#     'roadAddress': '서울특별시 용산구 한강대로23길 55 HDC아이파크몰 패션파크 3층',
#     'mapx': '308809',
#     'mapy': '547994'},
#    {'title': '<b>준오헤어</b> 교대역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-593-1605',
#     'address': '서울특별시 서초구 서초동 1689-1',
#     'roadAddress': '서울특별시 서초구 서초대로 331',
#     'mapx': '313330',
#     'mapy': '544120'},
#    {'title': '<b>준오헤어</b> 신논현역점',
#     'link': 'http://www.instagram.com/junosnh',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2052-0605',
#     'address': '서울특별시 강남구 역삼동 809',
#     'roadAddress': '서울특별시 강남구 강남대로 464 2층',
#     'mapx': '314023',
#     'mapy': '545067'},
#    {'title': '<b>준오헤어</b> 이대1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-392-6050',
#     'address': '서울특별시 서대문구 대현동 54-8',
#     'roadAddress': '서울특별시 서대문구 이화여대길 28',
#     'mapx': '307065',
#     'mapy': '551190'},
#    {'title': '<b>준오헤어</b> 돈암1호점',
#     'link': 'https://blog.naver.com/ehsdka1gh',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-929-0605',
#     'address': '서울특별시 성북구 동선동1가 60',
#     'roadAddress': '서울특별시 성북구 동소문로22길 44',
#     'mapx': '313488',
#     'mapy': '554783'},
#    {'title': '<b>준오헤어</b> 명동1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-756-3141',
#     'address': '서울특별시 중구 명동2가 52-8',
#     'roadAddress': '서울특별시 중구 명동6길 29',
#     'mapx': '310484',
#     'mapy': '551582'},
#    {'title': '<b>준오헤어</b> 코엑스도심공항점',
#     'link': 'https://instagram.com/juno_coexdosim',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2016-6050',
#     'address': '서울특별시 강남구 삼성동 159',
#     'roadAddress': '서울특별시 강남구 테헤란로87길 36 도심공항타워 B2층 B22호',
#     'mapx': '316962',
#     'mapy': '545769'}]},
#  {'lastBuildDate': 'Mon, 06 Apr 2020 19:58:32 +0900',
#   'total': 106,
#   'start': 61,
#   'display': 30,
#   'items': [{'title': '<b>준오헤어</b> 은평롯데몰점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-6975-5075',
#     'address': '서울특별시 은평구 진관동 63',
#     'roadAddress': '서울특별시 은평구 통일로 1050 롯데몰 은평점 지하1층 준오헤어',
#     'mapx': '304694',
#     'mapy': '560023'},
#    {'title': '<b>준오헤어</b> 명동4호점',
#     'link': 'http://myungdong4.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3789-0650',
#     'address': '서울특별시 중구 명동2가 51-3',
#     'roadAddress': '서울특별시 중구 명동8길 14',
#     'mapx': '310485',
#     'mapy': '551695'},
#    {'title': '<b>준오헤어</b> 길동역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-472-0605',
#     'address': '서울특별시 강동구 길동 391-4',
#     'roadAddress': '서울특별시 강동구 양재대로 1484 3층 준오헤어',
#     'mapx': '324233',
#     'mapy': '548786'},
#    {'title': '<b>준오헤어</b> 내방역점',
#     'link': 'https://junonb.modoo.at',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-588-0605',
#     'address': '서울특별시 서초구 방배동 935-40',
#     'roadAddress': '서울특별시 서초구 방배로 141 극동빌딩 3층',
#     'mapx': '311242',
#     'mapy': '543178'},
#    {'title': '<b>준오헤어</b> 사당역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-583-0605',
#     'address': '서울특별시 서초구 방배동 443-5',
#     'roadAddress': '서울특별시 서초구 동작대로 22',
#     'mapx': '310171',
#     'mapy': '542306'},
#    {'title': '<b>준오헤어</b> 건대역2호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-497-6050',
#     'address': '서울특별시 광진구 화양동 5-84',
#     'roadAddress': '서울특별시 광진구 능동로 109 2층',
#     'mapx': '318086',
#     'mapy': '549148'},
#    {'title': '<b>준오헤어</b> 압구정로데오 2호점',
#     'link': 'http://www.junohair.com',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-516-2605',
#     'address': '서울특별시 강남구 신사동 661-9',
#     'roadAddress': '서울특별시 강남구 선릉로161길 16',
#     'mapx': '315282',
#     'mapy': '547688'},
#    {'title': '<b>준오헤어</b> 동대문홈플러스점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 동대문구 용두동 33-1',
#     'roadAddress': '서울특별시 동대문구 천호대로 133 지하 1층',
#     'mapx': '315275',
#     'mapy': '552895'},
#    {'title': '<b>준오헤어</b> 수유역점',
#     'link': 'http://hairshop.kakao.com/4029',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-997-0605',
#     'address': '서울특별시 강북구 번동 446-24',
#     'roadAddress': '서울특별시 강북구 도봉로 332',
#     'mapx': '314199',
#     'mapy': '559900'},
#    {'title': '<b>준오헤어</b> 마리오아울렛점',
#     'link': 'https://www.instagram.com/juno_mario_official/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2067-2406',
#     'address': '서울특별시 금천구 가산동 60-20',
#     'roadAddress': '서울특별시 금천구 벚꽃로 266',
#     'mapx': '301589',
#     'mapy': '542411'},
#    {'title': '<b>준오헤어</b> 홍대1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3142-0621',
#     'address': '서울특별시 마포구 서교동 358-2',
#     'roadAddress': '서울특별시 마포구 홍익로 17',
#     'mapx': '305023',
#     'mapy': '550730'},
#    {'title': '<b>준오헤어</b> 코엑스몰점',
#     'link': 'https://www.instagram.com/juno_coex/?hl=ko',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3453-0605',
#     'address': '서울특별시 강남구 삼성동 159-6',
#     'roadAddress': '서울특별시 강남구 테헤란로87길 22',
#     'mapx': '317067',
#     'mapy': '545679'},
#    {'title': '<b>준오헤어</b> 영등포빅마켓점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2671-0605',
#     'address': '서울특별시 영등포구 영등포동8가 62-1',
#     'roadAddress': '서울특별시 영등포구 영중로 125',
#     'mapx': '303416',
#     'mapy': '547825'},
#    {'title': '<b>준오헤어</b> 이대3호점',
#     'link': 'http://blog.naver.com/eom9867',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-364-6605',
#     'address': '서울특별시 서대문구 대현동 37-39',
#     'roadAddress': '서울특별시 서대문구 이화여대길 81',
#     'mapx': '306895',
#     'mapy': '551286'},
#    {'title': '<b>준오헤어</b> 명동2호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-757-0605',
#     'address': '서울특별시 중구 충무로1가 22-4',
#     'roadAddress': '서울특별시 중구 명동8나길 18 인송빌딩 3층',
#     'mapx': '310436',
#     'mapy': '551532'},
#    {'title': '<b>준오헤어</b> 신림역2호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-6237-0605',
#     'address': '서울특별시 관악구 신림동 1638-16',
#     'roadAddress': '서울특별시 관악구 신림로 315',
#     'mapx': '305532',
#     'mapy': '542808'},
#    {'title': '<b>준오헤어</b> 신사역세로수길점',
#     'link': 'https://junohairserosugil.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-517-0605',
#     'address': '서울특별시 강남구 신사동 536-3',
#     'roadAddress': '서울특별시 강남구 도산대로11길 18 운산빌딩 2층 준오헤어',
#     'mapx': '313808',
#     'mapy': '546726'},
#    {'title': '<b>준오헤어</b> 강남레드점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-596-0605',
#     'address': '서울특별시 서초구 서초동 1307-19',
#     'roadAddress': '서울특별시 서초구 서초대로77길 27',
#     'mapx': '314037',
#     'mapy': '544674'},
#    {'title': '<b>준오헤어</b> 당산역점',
#     'link': 'https://www.instagram.com/junoydp/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2637-0605',
#     'address': '서울특별시 영등포구 당산동6가 304-1',
#     'roadAddress': '서울특별시 영등포구 당산로 231',
#     'mapx': '303143',
#     'mapy': '548602'},
#    {'title': '<b>준오헤어</b> 신내점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3423-0605',
#     'address': '서울특별시 중랑구 신내동 644',
#     'roadAddress': '서울특별시 중랑구 신내로 193',
#     'mapx': '320258',
#     'mapy': '557409'},
#    {'title': '<b>준오헤어</b> 양재2호점',
#     'link': 'https://blog.naver.com/junoyj02',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2057-0605',
#     'address': '서울특별시 서초구 양재동 12-3',
#     'roadAddress': '서울특별시 서초구 남부순환로350길 4 2층',
#     'mapx': '314875',
#     'mapy': '542906'},
#    {'title': '<b>준오헤어</b> 현대시티몰가든파이브점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2157-0605',
#     'address': '서울특별시 송파구 문정동 634',
#     'roadAddress': '서울특별시 송파구 충민로 66 현대시티몰 가든파이브점 아울렛관 5층',
#     'mapx': '322804',
#     'mapy': '542142'},
#    {'title': '<b>준오헤어</b> 신내홈플러스점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3422-0605',
#     'address': '서울특별시 중랑구 신내동 645',
#     'roadAddress': '서울특별시 중랑구 신내로 201',
#     'mapx': '320165',
#     'mapy': '557482'},
#    {'title': '<b>준오헤어</b> 반포점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3478-0605',
#     'address': '서울특별시 서초구 반포동 56-2',
#     'roadAddress': '서울특별시 서초구 서초중앙로 239 2층 준오헤어 반포점',
#     'mapx': '312759',
#     'mapy': '544999'},
#    {'title': '<b>준오헤어</b> 목동 이마트점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2062-0605',
#     'address': '서울특별시 양천구 목동 962',
#     'roadAddress': '서울특별시 양천구 오목로 299 이마트 지하2층',
#     'mapx': '300385',
#     'mapy': '547663'},
#    {'title': '<b>준오헤어</b> 강남1호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-556-7488',
#     'address': '서울특별시 강남구 역삼동 816-4',
#     'roadAddress': '서울특별시 강남구 강남대로96길 5 3층',
#     'mapx': '314207',
#     'mapy': '544633'},
#    {'title': '<b>준오헤어</b> 건대역1호점',
#     'link': 'http://hairshop.kakao.com/store/4025',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-426-0605',
#     'address': '서울특별시 광진구 화양동 4-20',
#     'roadAddress': '서울특별시 광진구 능동로 110',
#     'mapx': '318139',
#     'mapy': '549123'},
#    {'title': '<b>준오헤어</b> 은평뉴타운점',
#     'link': 'https://www.facebook.com/junohair.official/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-383-0605',
#     'address': '서울특별시 은평구 진관동 64',
#     'roadAddress': '서울특별시 은평구 진관3로 11',
#     'mapx': '304729',
#     'mapy': '560237'},
#    {'title': '<b>준오헤어</b> 강남화이트점',
#     'link': 'http://junoknwhite.modoo.at/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-592-0605',
#     'address': '서울특별시 서초구 서초동 1317-7',
#     'roadAddress': '서울특별시 서초구 서초대로77길 13 3층',
#     'mapx': '314097',
#     'mapy': '544535'},
#    {'title': '<b>준오헤어</b> 가든도산공원점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-544-0605',
#     'address': '서울특별시 강남구 논현동 92',
#     'roadAddress': '서울특별시 강남구 도산대로 318 SB타워 별관 A동 3층 준오헤어',
#     'mapx': '315042',
#     'mapy': '547048'}]},
#  {'lastBuildDate': 'Mon, 06 Apr 2020 19:58:32 +0900',
#   'total': 106,
#   'start': 91,
#   'display': 16,
#   'items': [{'title': '<b>준오헤어</b> 홍대입구역점',
#     'link': 'https://www.instagram.com/junohair_hds/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-336-6050',
#     'address': '서울특별시 마포구 동교동 156-2',
#     'roadAddress': '서울특별시 마포구 양화로 175',
#     'mapx': '305180',
#     'mapy': '551163'},
#    {'title': '<b>준오헤어</b> 강서홈플러스점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-3662-6050',
#     'address': '서울특별시 강서구 등촌동 639-11',
#     'roadAddress': '서울특별시 강서구 화곡로 398',
#     'mapx': '298994',
#     'mapy': '551343'},
#    {'title': '<b>준오헤어</b> 마곡역점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2664-0605',
#     'address': '서울특별시 강서구 마곡동 799-5',
#     'roadAddress': '서울특별시 강서구 마곡중앙로 56 마곡사이언스타워2 2층 211호',
#     'mapx': '296576',
#     'mapy': '551319'},
#    {'title': '<b>준오헤어</b> 신촌연대점',
#     'link': 'http://www.instagram.com/juno_yd1/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-325-6050',
#     'address': '서울특별시 서대문구 창천동 33-4',
#     'roadAddress': '서울특별시 서대문구 연세로 37 3층 준오헤어 신촌연대점',
#     'mapx': '306257',
#     'mapy': '551271'},
#    {'title': '<b>준오헤어</b> 압구정역블랙점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-514-0605',
#     'address': '서울특별시 강남구 신사동 578-1',
#     'roadAddress': '서울특별시 강남구 논현로175길 11 일상빌딩 2층',
#     'mapx': '314253',
#     'mapy': '547538'},
#    {'title': '<b>준오헤어</b> 선릉역2호점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2051-0605',
#     'address': '서울특별시 강남구 삼성동 140-26',
#     'roadAddress': '서울특별시 강남구 선릉로94길 3 3층 준오헤어',
#     'mapx': '316101',
#     'mapy': '545285'},
#    {'title': '<b>준오헤어</b>',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 용산구 보광동 265-812',
#     'roadAddress': '서울특별시 용산구 우사단로10길 118',
#     'mapx': '311943',
#     'mapy': '548143'},
#    {'title': '<b>준오헤어</b> 포스코사거리점',
#     'link': 'http://junohair.com/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-539-0605',
#     'address': '서울특별시 강남구 대치동 891-44 노벨빌딩 2층',
#     'roadAddress': '서울특별시 강남구 테헤란로78길 16 노벨빌딩 2층',
#     'mapx': '316679',
#     'mapy': '545190'},
#    {'title': '<b>준오헤어</b>뷰',
#     'link': '',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 광진구 군자동 364-4',
#     'roadAddress': '서울특별시 광진구 군자로 94',
#     'mapx': '318137',
#     'mapy': '550330'},
#    {'title': '애브뉴준오',
#     'link': 'http://junohair.com/avenuejuno/',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-2138-0605',
#     'address': '서울특별시 강남구 청담동 63-14',
#     'roadAddress': '서울특별시 강남구 삼성로 728 준오헤어 청담동 사옥',
#     'mapx': '316184',
#     'mapy': '546935'},
#    {'title': '리소헤어 천호점',
#     'link': 'http://lisohair40.cusmore.com/',
#     'category': '미용>미용실',
#     'description': '',
#     'telephone': '02-486-7942',
#     'address': '서울특별시 강동구 천호동 456',
#     'roadAddress': '서울특별시 강동구 천호대로 997',
#     'mapx': '322732',
#     'mapy': '548945'},
#    {'title': '정인헤어',
#     'link': '',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 노원구 상계동 730-2',
#     'roadAddress': '서울특별시 노원구 동일로 1383 주공3단지 302동상가 210호',
#     'mapx': '317305',
#     'mapy': '561551'},
#    {'title': '최고헤어',
#     'link': '',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '02-7878-1346',
#     'address': '서울특별시 강남구 역삼동 818-15',
#     'roadAddress': '서울특별시 강남구 테헤란로1길 16 202호',
#     'mapx': '314248',
#     'mapy': '544590'},
#    {'title': '김미현헤어',
#     'link': 'http://storefarm.naver.com/dongjuya4318',
#     'category': '생활,편의>미용실',
#     'description': '',
#     'telephone': '',
#     'address': '서울특별시 용산구 청파동2가 3-1',
#     'roadAddress': '서울특별시 용산구 효창원로93길 2',
#     'mapx': '308616',
#     'mapy': '550108'},
#    {'title': '준오뷰티',
#     'link': '',
#     'category': '서비스,산업>기업',
#     'description': '',
#     'telephone': '02-548-0605',
#     'address': '서울특별시 강남구 청담동 63-14 준오헤어청담동사옥 5층',
#     'roadAddress': '서울특별시 강남구 삼성로 728 애브뉴준오 5층',
#     'mapx': '316186',
#     'mapy': '546938'},
#    {'title': '비에비스나무병원',
#     'link': 'http://www.vievisnamuh.com/',
#     'category': '병원,의원>내과',
#     'description': '',
#     'telephone': '1577-7502',
#     'address': '서울특별시 강남구 논현동 175-10',
#     'roadAddress': '서울특별시 강남구 논현로 627 준오헤어빌딩',
#     'mapx': '314646',
#     'mapy': '545699'}]}]

# %%
# 검색결과인 'items' key에 해당하는 value 만 뽑기
item_list_naver = list(map(lambda x: x['items'], dict_list_naver))

# %%
# 리스트에 저장된 각각의 데이터를 DataFrame으로 말기
df_list_naver = list(map(lambda x: DataFrame(x), item_list_naver))

# %%
# 리스트의 모든 DF를 하나로 합치기
df_all_naver = pd.concat(df_list_naver, ignore_index=True)

# %%
# 필요한 컬럼으로 재색인
df_all_naver = df_all_naver.reindex(columns = ['title', 'telephone', 'address', 'roadAddress'])

# %%
# 'title'에 들어간 '<br>', '</br>' 등 html 태그 지우기
df_all_naver['title'] = np.array(list(map(lambda x: re.sub('</\w+>|<\w+>','',x), df_all_naver['title'].values)))

# %%
# 결과 확인
# 105개 total_count만큼 잘 조회가 되었다.
# 그런데 준오헤어가 아닌 데이터들이 포함된 것 같다.

df_all_naver.tail(2)
# Out:
#         title    telephone                           address  \
# 104      준오뷰티  02-548-0605  서울특별시 강남구 청담동 63-14 준오헤어청담동사옥 5층
# 105  비에비스나무병원    1577-7502              서울특별시 강남구 논현동 175-10
#
#                     roadAddress
# 104  서울특별시 강남구 삼성로 728 애브뉴준오 5층
# 105    서울특별시 강남구 논현로 627 준오헤어빌딩

# %%
# 80번부터 끝까지 조회
# 97번부터 이상한 데이터가 들어가있다.

df_all_naver.iloc[80:]
# Out:
#                 title     telephone                           address  \
# 80         준오헤어 양재2호점  02-2057-0605                서울특별시 서초구 양재동 12-3
# 81   준오헤어 현대시티몰가든파이브점  02-2157-0605                 서울특별시 송파구 문정동 634
# 82       준오헤어 신내홈플러스점  02-3422-0605                 서울특별시 중랑구 신내동 645
# 83           준오헤어 반포점  02-3478-0605                서울특별시 서초구 반포동 56-2
# 84       준오헤어 목동 이마트점  02-2062-0605                  서울특별시 양천구 목동 962
# 85         준오헤어 강남1호점   02-556-7488               서울특별시 강남구 역삼동 816-4
# 86        준오헤어 건대역1호점   02-426-0605                서울특별시 광진구 화양동 4-20
# 87        준오헤어 은평뉴타운점   02-383-0605                  서울특별시 은평구 진관동 64
# 88        준오헤어 강남화이트점   02-592-0605              서울특별시 서초구 서초동 1317-7
# 89       준오헤어 가든도산공원점   02-544-0605                  서울특별시 강남구 논현동 92
# 90        준오헤어 홍대입구역점   02-336-6050               서울특별시 마포구 동교동 156-2
# 91       준오헤어 강서홈플러스점  02-3662-6050              서울특별시 강서구 등촌동 639-11
# 92          준오헤어 마곡역점  02-2664-0605               서울특별시 강서구 마곡동 799-5
# 93         준오헤어 신촌연대점   02-325-6050               서울특별시 서대문구 창천동 33-4
# 94       준오헤어 압구정역블랙점   02-514-0605               서울특별시 강남구 신사동 578-1
# 95        준오헤어 선릉역2호점  02-2051-0605              서울특별시 강남구 삼성동 140-26
# 96               준오헤어                           서울특별시 용산구 보광동 265-812
# 97       준오헤어 포스코사거리점   02-539-0605      서울특별시 강남구 대치동 891-44 노벨빌딩 2층
# 98              준오헤어뷰                             서울특별시 광진구 군자동 364-4
# 99              애브뉴준오  02-2138-0605               서울특별시 강남구 청담동 63-14
# 100          리소헤어 천호점   02-486-7942                 서울특별시 강동구 천호동 456
# 101              정인헤어                             서울특별시 노원구 상계동 730-2
# 102              최고헤어  02-7878-1346              서울특별시 강남구 역삼동 818-15
# 103             김미현헤어                             서울특별시 용산구 청파동2가 3-1
# 104              준오뷰티   02-548-0605  서울특별시 강남구 청담동 63-14 준오헤어청담동사옥 5층
# 105          비에비스나무병원     1577-7502              서울특별시 강남구 논현동 175-10
#
#                                roadAddress
# 80                서울특별시 서초구 남부순환로350길 4 2층
# 81   서울특별시 송파구 충민로 66 현대시티몰 가든파이브점 아울렛관 5층
# 82                       서울특별시 중랑구 신내로 201
# 83         서울특별시 서초구 서초중앙로 239 2층 준오헤어 반포점
# 84              서울특별시 양천구 오목로 299 이마트 지하2층
# 85                  서울특별시 강남구 강남대로96길 5 3층
# 86                       서울특별시 광진구 능동로 110
# 87                       서울특별시 은평구 진관3로 11
# 88                 서울특별시 서초구 서초대로77길 13 3층
# 89   서울특별시 강남구 도산대로 318 SB타워 별관 A동 3층 준오헤어
# 90                       서울특별시 마포구 양화로 175
# 91                       서울특별시 강서구 화곡로 398
# 92    서울특별시 강서구 마곡중앙로 56 마곡사이언스타워2 2층 211호
# 93         서울특별시 서대문구 연세로 37 3층 준오헤어 신촌연대점
# 94            서울특별시 강남구 논현로175길 11 일상빌딩 2층
# 95              서울특별시 강남구 선릉로94길 3 3층 준오헤어
# 96                   서울특별시 용산구 우사단로10길 118
# 97            서울특별시 강남구 테헤란로78길 16 노벨빌딩 2층
# 98                        서울특별시 광진구 군자로 94
# 99           서울특별시 강남구 삼성로 728 준오헤어 청담동 사옥
# 100                     서울특별시 강동구 천호대로 997
# 101   서울특별시 노원구 동일로 1383 주공3단지 302동상가 210호
# 102               서울특별시 강남구 테헤란로1길 16 202호
# 103                    서울특별시 용산구 효창원로93길 2
# 104             서울특별시 강남구 삼성로 728 애브뉴준오 5층
# 105               서울특별시 강남구 논현로 627 준오헤어빌딩
